# %%
import pandas as pd
df= pd.read_csv('salesdata.csv')

# %%
df.head() ##Checking the first five data on the table
# Out:
#    ORDERNUMBER   QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107                30      95.70                2  2871.00
# 1        10121                34      81.35                5  2765.90
# 2        10134                41      94.74                2  3884.34
# 3        10145                45      83.26                6  3746.70
# 4        10159                49     100.00               14  5205.27
#
#          ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00   Shipped       1         2     2003  ...
# 1    5/7/2003 0:00   Shipped       2         5     2003  ...
# 2    7/1/2003 0:00   Shipped       3         7     2003  ...
# 3   8/25/2003 0:00   Shipped       3         8     2003  ...
# 4  10/10/2003 0:00   Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
df.info() ## showing the table information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2823 non-null   int64
#  1    QUANTITYORDERED  2823 non-null   int64
#  2   PRICEEACH         2823 non-null   float64
#  3   ORDERLINENUMBER   2823 non-null   int64
#  4   SALES             2823 non-null   float64
#  5   ORDERDATE         2823 non-null   object
#  6   STATUS            2823 non-null   object
#  7   QTR_ID            2823 non-null   int64
#  8   MONTH_ID          2823 non-null   int64
#  9   YEAR_ID           2823 non-null   int64
#  10  PRODUCTLINE       2823 non-null   object
#  11  MSRP              2823 non-null   int64
#  12  PRODUCTCODE       2823 non-null   object
#  13  CUSTOMERNAME      2823 non-null   object
#  14  PHONE             2823 non-null   object
#  15  ADDRESSLINE1      2823 non-null   object
# ...

# %%
df.columns ## checking the columns
# Out:
# Index(['ORDERNUMBER', ' QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'ORDERDATE', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID',
#        'PRODUCTLINE', 'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE',
#        'ADDRESSLINE1', 'ADDRESSLINE2', 'CITY', 'STATE', 'POSTALCODE',
#        'COUNTRY', 'TERRITORY', 'CONTACTLASTNAME', 'CONTACTFIRSTNAME',
#        'DEALSIZE'],
#       dtype='object')

# %%
newdf = df[['SALES', 'ORDERDATE', 'STATUS', 'PRODUCTLINE', 'COUNTRY', 'DEALSIZE']] ## picking out the specified data needed for exploration

# %%
newdf.head()
# Out:
#      SALES        ORDERDATE    STATUS   PRODUCTLINE COUNTRY DEALSIZE
# 0  2871.00   2/24/2003 0:00   Shipped   Motorcycles     USA    Small
# 1  2765.90    5/7/2003 0:00   Shipped   Motorcycles  France    Small
# 2  3884.34    7/1/2003 0:00   Shipped   Motorcycles  France   Medium
# 3  3746.70   8/25/2003 0:00   Shipped   Motorcycles     USA   Medium
# 4  5205.27  10/10/2003 0:00   Shipped   Motorcycles     USA   Medium

# %%
 newdf.isna().sum() ##checking for nan values
# Out:
# SALES          0
# ORDERDATE      0
# STATUS         0
# PRODUCTLINE    0
# COUNTRY        0
# DEALSIZE       0
# dtype: int64

# %%
newdf.dtypes ## checking for data types
# Out:
# SALES          float64
# ORDERDATE       object
# STATUS          object
# PRODUCTLINE     object
# COUNTRY         object
# DEALSIZE        object
# dtype: object

# %%
newdf.STATUS.value_counts() ## checking for the informations in the status column
# Out:
# STATUS
# Shipped       2616
# Cancelled       60
# Resolved        47
# On Hold         44
# In Process      41
# Disputed        14
#  Shipped         1
# Name: count, dtype: int64

# %%
newdf.PRODUCTLINE.value_counts() ## checking for the informations in the productline column
# Out:
# PRODUCTLINE
# Classic Cars        967
# Vintage Cars        607
# Motorcycles         330
# Planes              306
# Trucks and Buses    301
# Ships               234
# Trains               77
#  Motorcycles          1
# Name: count, dtype: int64

# %%
newdf.COUNTRY.value_counts()  ## checking for the informations in the country column
# Out:
# COUNTRY
# USA            1003
# Spain           342
# France          314
# Australia       185
# UK              144
# Italy           113
# Finland          92
# Norway           85
# Singapore        79
# Canada           70
# Denmark          63
# Germany          62
# Sweden           57
# Austria          55
# Japan            52
# Belgium          33
# Switzerland      31
# Philippines      26
# Ireland          16
#  USA              1
# Name: count, dtype: int64

# %%
newdf.DEALSIZE.value_counts()  ## checking for the informations in the Dealsize column
# Out:
# DEALSIZE
# Medium    1384
# Small     1281
# Large      157
#  Small       1
# Name: count, dtype: int64

# %%
newdf.to_csv('Cleanedsalesdata10.csv', index=False)
